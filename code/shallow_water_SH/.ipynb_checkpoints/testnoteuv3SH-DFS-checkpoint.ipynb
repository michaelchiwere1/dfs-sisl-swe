# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# Williamson II

# %%
# shifted grid W1
ss = np.zeros((8,3))
ss[0,0] =xr.open_dataset("w2a.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[1,0] =xr.open_dataset("w2b.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[2,0] =xr.open_dataset("w2c.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[3,0] =xr.open_dataset("w2d.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[4,0] =xr.open_dataset("w2e.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[5,0] =xr.open_dataset("w2f.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[6,0] =xr.open_dataset("w2g.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[7,0] =xr.open_dataset("w2h.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss[0,1] =xr.open_dataset("w2a.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[1,1] =xr.open_dataset("w2b.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[2,1] =xr.open_dataset("w2c.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[3,1] =xr.open_dataset("w2d.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[4,1] =xr.open_dataset("w2e.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[5,1] =xr.open_dataset("w2f.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[6,1] =xr.open_dataset("w2g.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[7,1] =xr.open_dataset("w2h.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss[0,2] =xr.open_dataset("w2a.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[1,2] =xr.open_dataset("w2b.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[2,2] =xr.open_dataset("w2c.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[3,2] =xr.open_dataset("w2d.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[4,2] =xr.open_dataset("w2e.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[5,2] =xr.open_dataset("w2f.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[6,2] =xr.open_dataset("w2g.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss[7,2] =xr.open_dataset("w2h.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]

ss1 = np.zeros((8,3))
ss1[0,0] =xr.open_dataset("../shallow_water_DFS/w2a.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[1,0] =xr.open_dataset("../shallow_water_DFS/w2b.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[2,0] =xr.open_dataset("../shallow_water_DFS/w2c.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[3,0] =xr.open_dataset("../shallow_water_DFS/w2d.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[4,0] =xr.open_dataset("../shallow_water_DFS/w2e.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[5,0] =xr.open_dataset("../shallow_water_DFS/w2f.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[6,0] =xr.open_dataset("../shallow_water_DFS/w2g.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[7,0] =xr.open_dataset("../shallow_water_DFS/w2h.nc")['norm_l1'].sel(lat=0.0, lon=0.0).values[-1]
ss1[0,1] =xr.open_dataset("../shallow_water_DFS/w2a.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[1,1] =xr.open_dataset("../shallow_water_DFS/w2b.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[2,1] =xr.open_dataset("../shallow_water_DFS/w2c.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[3,1] =xr.open_dataset("../shallow_water_DFS/w2d.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[4,1] =xr.open_dataset("../shallow_water_DFS/w2e.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[5,1] =xr.open_dataset("../shallow_water_DFS/w2f.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[6,1] =xr.open_dataset("../shallow_water_DFS/w2g.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[7,1] =xr.open_dataset("../shallow_water_DFS/w2h.nc")['norm_l2'].sel(lat=0.0, lon=0.0).values[-1]
ss1[0,2] =xr.open_dataset("../shallow_water_DFS/w2a.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[1,2] =xr.open_dataset("../shallow_water_DFS/w2b.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[2,2] =xr.open_dataset("../shallow_water_DFS/w2c.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[3,2] =xr.open_dataset("../shallow_water_DFS/w2d.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[4,2] =xr.open_dataset("../shallow_water_DFS/w2e.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[5,2] =xr.open_dataset("../shallow_water_DFS/w2f.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[6,2] =xr.open_dataset("../shallow_water_DFS/w2g.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]
ss1[7,2] =xr.open_dataset("../shallow_water_DFS/w2h.nc")['norm_lmax'].sel(lat=0.0, lon=0.0).values[-1]

# %%
#Plotting the evolution of the errors

#TIMESTEPS
NN = np.array([3600/i for i in [1, 2, 4, 8, 16, 32, 64, 128]])


fig, (ax1, ax2,  ax3) = plt.subplots(1, 3, figsize=(20, 6))

ax1.loglog(NN , ss[:,0],'b.-',label="DFS Method")
ax1.loglog(NN, ss1[:,0],'rd-', label='SH Method')

ax1.legend()
ax1.set_title("L1-norm of  the Error")
ax1.set_ylabel("Error")
ax1.set_xlabel("N")

ax2.loglog(NN, ss[:,1],'b.-',label="DFS Method")
ax2.loglog(NN, ss1[:,1],'rd-', label='SH Method')
ax2.legend()
ax2.set_title("L2-norm of  the Error")
ax2.set_ylabel("Error")
ax2.set_xlabel("N")

ax3.loglog(NN, ss[:,2],'b.-',label="DFS  Method")
ax3.loglog(NN, ss1[:,2],'rd-', label='SH Method')
ax3.legend()
ax3.set_title("Max-norm of  the Error")
ax3.set_ylabel("Error")
ax3.set_xlabel("N")
plt.rcParams.update({'font.size': 18})
fig.tight_layout()
plt.show()

# %%
np.polyfit(np.log(NN),np.log(ss1), 1)
# Out:
# array([[  1.94998466,   1.95241225,   1.95001941],
#        [-28.58967004, -28.50442735, -28.13239487]])

# %%
np.polyfit(np.log(NN),np.log(ss), 1)
# Out:
# array([[  1.93224658,   1.93310069,   1.92590889],
#        [-28.46813984, -28.37217415, -27.96723243]])
